# %% [markdown]
# # Запуск
# ### В этом ноутбуке вы можете сами запустить модели и получить вероятность болезни ткани по показаниям спектроскопии

# %% [markdown]
# ### В переменную `path_to_sample` укажите путь до файла с показаниями

# %%
from data.prep_module import *
prep = Prep()

# 1D
# path_to_sample = "dataset\healthy\image_cortex_patient15012020_633nm_obj20_power100_1sec_acc1_сenter2900_place1_dots20x15_10um_20210202_12.txt"
# path_to_sample = "dataset\healthy\image_cortex_patient15012020_633nm_obj20_power100_1sec_acc1_сenter2900_place1_dots20x15_10um_20210209_14.txt"
# path_to_sample = "dataset\sick\image_tumor_patient20022019_633nm_obj20_power100_1sec_сenter2900_step4um_place1_20200929_1_17.txt"
# path_to_sample = "dataset\sick\image_tumor_patient20022019_633nm_obj20_power100_1sec_сenter2900_step4um_place1_20200929_1_20.txt"

# 2D
# path_to_sample = "dataset2D\healthy\image_cortex_patient78_633nm_obj20_power100_step4um_2sec_acc1_сenter2900_place1_20201016.txt"
# path_to_sample = "dataset2D\\near-tumor\image_pretumor_patient20022019_633nm_obj20_power100_1sec_4um_сenter2900_place1_20200929_1.txt"
# path_to_sample = "dataset2D\sick\image_tumor_patient20022019_633nm_obj20_power100_1sec_сenter2900_step4um_place1_20200929_1.txt"
# path_to_sample = "dataset2D\sick\image_tumor_patient25022020_633nm_obj20_power100_1sec_сenter2900_step4um_place1_20200925_1.txt"

prep.get_results(path_to_sample)
# Out:
# green for healthy
# red for sick
# yellow for near-tumor
